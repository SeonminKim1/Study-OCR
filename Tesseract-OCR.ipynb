# %% [markdown]
# ## Tesseract로 OCR 하기
# - 다양한 운영체제에서 사용가능한 광학 문자 인식 엔진, 무료 소프트웨어
#
# - https://github.com/UB-Mannheim/tesseract/wiki // Window 프로그램에 설치 및 환경변수 등록
#
# ### # 1. Tesseract Windows 버전 설치
# - https://github.com/UB-Mannheim/tesseract/wiki
# - 설치시 한국어 버전 설치
#
# ### # 2. 환경변수 등록
# - 설치 폴더 환경변수 등록
#
# ### # 3. python, anaconda 명령어로 설치
# - conda install -c conda-forge pytesseract
#
# ### # 4. 한글 OCR Trainin data 추가 다운로드
# - https://github.com/tesseract-ocr/ 링크 이용
# - testdata 레퍼지토리
#     - 일반 trained 결과 (추후 재학습시 여기서)
#     - testdata의 kor.traineddata와 kor_vert.traineddata 다운로드
# - testdata_best 레퍼지토리
#     - 최고의 accuracy 결과를 보임
#     - testbest_data의 kor.traineddata와 kor_vert.traineddata 다운로드
# - C:\Program Files\Tesseract-OCR\tessdata 링크에서 파일변경
#
# ### # 주의사항
# - 고딕류 계열의 글씨만 정확도가 좋음.
# - 궁서 잘 안됨.
#
# ### # 참조링크
# - https://www.youtube.com/watch?v=rNxMwtottmM

# %%
# 기본 pytesseract 사용
file_name = 'img/test_image.PNG'

from PIL import Image
import pytesseract

# 젤먼저 pytesseract가 어딨는지 경로 설정 필요
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

img = Image.open(file_name)#.convert('L')

text = pytesseract.image_to_string(img, lang='kor')

print(text.replace(" ", "").replace('\n\n','\n'))
# Out:
# #ㅇ68(00403!다13136860090미400)
#
# 문자인식(008,06013!다(3686009000))은사람이쓰거나기계로인쇄한
# 자의영상을이미지스캐너로획득하여기계가읽을수있(로변환하는것
#
# 글자영역탐지(@8허660007)와*글자인식6166090400)*의두단계과정을
# 거침

# %% [markdown]
# ---
#
# ## PDF OCR
# - pdf 한페이지씩 ocr 로 변환하여 진행
#
# ### PDF to Image
# - pdf2image library 사용하여 변환
#
# ### 설치 library
# - conda install -c conda-forge poppler
# - conda install -c conda-forge pdf2image

# %%
## 맑은고딕 

import os
from PIL import Image
from pdf2image import convert_from_path
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

filePath = 'pdf/아이유노래가사_맑은고딕.pdf'

doc = convert_from_path(filePath) # doc는 PIL.PpmImageFile list

# 파일 경로, 파일 이름(확장자포함) 구하기
path, fileName = os.path.split(filePath) # path, 파일name.pdf
print('path:', path, 'filename:', fileName)

# 파일 이름, 파일 확장자 구하기
fileBaseName, fileExtension = os.path.splitext(fileName)
print('fileBaseName:', fileBaseName, 'fileExtension:', fileExtension)

for page_number, page_image in enumerate(doc):#
    txt = pytesseract.image_to_string(page_image, lang='kor').replace(' ', '')
    print("Page # {} - {}".format(str(page_number),txt.replace('\n\n','\n')))
# Out:
# path: pdf filename: 아이유노래가사_맑은고딕.pdf
# fileBaseName: 아이유노래가사_맑은고딕 fileExtension: .pdf
# Page # 0 - 1.아이유블루밍
# '뭐해?'라는두글자에
# "네가보고싶어'나의속마음을담아우
#
# 이모티콘하나하나속에
# 달라지는내미묘한심리를알까우
# 아니바쁘지않아001090000
# 잠들어있지않아11500ㅁ71307303
# 지금다른사람과함께이지않아
# 응,나도너를생각중
# 우리의네모칸은6000
# 엄지손가락으로장미꽃을피워
# 향기에취할것같아우
# 오직둘만의비밀의정원
# |66.60001666.600001666101000
# 너에게한송이를더보내
# 밤샘작업으로업데이트
# 흥미로운이작품의지은이1130506우
#
#
# 어찜이관계의클라이맥스
# 2막으로넘어가기엔지금이》0000409우
# 같은맘인걸알아(63126131126
# 고르지말아]4581601/13131/
# 조금장난스러운나의은유에
# 네해석이궁금히
# 우리의색은0『3/300046
# 엄지손가락으로말풍선을띄워
# 금세터질것같아우
# 호흡이가빠져어지러워
# |6616146.|76리이06.|(6리이66.
# 너에게가득히채워
# 띄어쓰기없이보낼게사랑인것같애
# 백만송이장미꽃을,나랑피워볼래?
# 꽃잎의색은우리마음가는대로칠해
# 도예쁘게
# |네모칸은(100
# 손가락으로장미3
# 향기에취할것같ㅇ
# 오직둘만의비밀의정원
# |66.60001666.600001666101000
# 너에게한송이를더보내
#
# 거무
# [|찌0|
#
#
#
#
#
# 건민띠
# 10
# 3
# 02ㅋ10
# 0
# 피
# ㅋ08
# 고으
#
#
#
#
#
#
#
#
#
#
# Page # 1 -
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 우리이별이꿈이아닌걸너무잘알고있는데
# 왜난깨어나길비는지
# 쏟아지는빗물은날한치앞도못보게해
# 몰아치는바람은단한걸음도못가게히
# 벼랑끝에서있는듯이난무서워떨고있지만
# 작은두손을모은내기도는하나뿐이
# ...

# %%
## 궁서

import os
from PIL import Image
from pdf2image import convert_from_path
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

filePath = 'pdf/아이유노래가사_궁서.pdf'
# filePath = 'pdf/2020학년도_국어_홀.pdf'
doc = convert_from_path(filePath) # doc는 PIL.PpmImageFile list

# 파일 경로, 파일 이름(확장자포함) 구하기
path, fileName = os.path.split(filePath) # path, 파일name.pdf
print('path:', path, 'filename:', fileName)

# 파일 이름, 파일 확장자 구하기
fileBaseName, fileExtension = os.path.splitext(fileName)
print('fileBaseName:', fileBaseName, 'fileExtension:', fileExtension)

for page_number, page_image in enumerate(doc):#
    txt = pytesseract.image_to_string(page_image, lang='kor').replace(' ', '')
    print("Page # {} - {}".format(str(page_number),txt.replace('\n\n','\n')))
# Out:
# path: pdf filename: 아이유노래가사_궁서.pdf
# fileBaseName: 아이유노래가사_궁서 fileExtension: .pdf
# Page # 0 - 국
# 12)
# 개페급가.유
# 풍큼2슈중구“
# 니므212느은스스
# 봉210데에제습이낭느사지주여시
# 9혁종눔송종늦더그영입,주늦딕이
# 악건。70디중누디6220이직(이
# 8[이옥으더정숭더후고저그페킬기근다
# 그아요님도6이에어긋곤머파마고가노기어않으
# ㅇㅇ@읍이으내머자머읽않아조그버니소
# 이8넘@딱버이|스막버너휴버르28막기?
# 악“[이]그은어3먹마버너주수매시기시이8팩
# (개업더06앙러점더안에시노후디23238애애딕객증오사버읍으습줄았2머
# 은아ㅇ더--니이관아시
# 점이음띠00-29000703;격0제제였산아2움수“이사동
# 해종음티티호88=8다도더흡수업아의제데쩌입|)따염산며바가9에액조이망년배모
# “이그으41000“이덩규와6으리학우2허가<져,72으으|
# 이이근자그ㅇ귀다궁으사(데슈이"한움기240아비어212093212이27120
# 호매음듬&입니240닌본30바기1사자아세담지가아=6600020909062어러딕큐염8언나
# 세웅전더엉이으틸악운덧긍※ㅇㅇ디야.헌바00그8않지-으섰이녀떨이,이2이27읍슴8만타이주이빅뮤눔<금주이강
# 중중6“0등)다설이이늘둥이2하얼바짝남틱엽고0버슈긋주이6[웅<긋
# 송하세응임조바이아,인진움하께장선유아든마항소이아진조입능승'^'너망찌주이입나금송고념<굿주고능1
# 으히세시요경조으주2호럴진눔하긍긍,눔영웅6퍼테나이것)버중중립승대8앤석22으수망간6=눌12|”조
# 섯암+0퍼애9노적어|업끼박지오상아슬엄적안이버사아리슈이819.소기이하애농당석이1221244440허
# 0고아수스담소9900,2너미06622에이조라우고이소너가수유8센먹숭꼭,,,29조우아쟁빠후하누으하빠눔
# 슴0,승떠공상전주앙벅숨>틈승너짜하슨0마이즈드비|「움값이?"머읍[70금견꽤,」.야의삽기기하백움이2앙이시요스긍긍급증
# ...

# %% [markdown]
# ---
#
# ## PDF to TEXT
# - conda install -c conda-forge pdfminer3k
# - conda install -c conda-forge pdfminer.six

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import HTMLConverter
# from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO
  
rsrcmgr = PDFResourceManager()
retstr = StringIO()
codec = 'utf-8'
laparams = LAParams()
 
f = open('result/out.html', 'wb')
device = HTMLConverter(rsrcmgr, f, codec=codec, laparams=laparams)
 
fp = open(filePath, 'rb')
interpreter = PDFPageInterpreter(rsrcmgr, device)
password = ""
maxpages = 0 #is for all
caching = True
pagenos=set()
for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
    interpreter.process_page(page)
fp.close()
device.close()
str = retstr.getvalue()
retstr.close()
f.close()
